# %%
# !python -V
# Out:
# Python 3.9.19

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-Experiment-tracking/mlruns/1', creation_time=1726570807518, experiment_id='1', last_update_time=1726570807518, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_csv(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2023-01.csv')
df_val = read_dataframe('./data/green_tripdata_2023-02.csv')
# Out:
# /tmp/ipykernel_2768/3970424726.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
len(df_train), len(df_val)
# Out:
# (65946, 62574)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# np.float64(6.037803764245777)

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2023-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2023-02.csv")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
# Out:
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [11:35:46] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.61299
# [1]	validation-rmse:8.01900
# [2]	validation-rmse:7.52461
# [3]	validation-rmse:7.11607
# [4]	validation-rmse:6.78018
# [5]	validation-rmse:6.50608
# [6]	validation-rmse:6.28445
# [7]	validation-rmse:6.10537
# [8]	validation-rmse:5.96202
# [9]	validation-rmse:5.84661
# [10]	validation-rmse:5.75391
# [11]	validation-rmse:5.67745
# [12]	validation-rmse:5.61782
# [13]	validation-rmse:5.56949
# [14]	validation-rmse:5.52962
# [15]	validation-rmse:5.49889
# [16]	validation-rmse:5.47407
# [17]	validation-rmse:5.45360
# [18]	validation-rmse:5.43307
# [19]	validation-rmse:5.41576
# [20]	validation-rmse:5.40179
# [21]	validation-rmse:5.38939
# [22]	validation-rmse:5.37887
# [23]	validation-rmse:5.36934
# [24]	validation-rmse:5.36149
# [25]	validation-rmse:5.35478
# [26]	validation-rmse:5.34876
# [27]	validation-rmse:5.34365
# [28]	validation-rmse:5.33950
# [29]	validation-rmse:5.33485
# [30]	validation-rmse:5.33064
# [31]	validation-rmse:5.32733
# [32]	validation-rmse:5.32379
# [33]	validation-rmse:5.32061
# [34]	validation-rmse:5.31836
# [35]	validation-rmse:5.31648
# [36]	validation-rmse:5.31369
# [37]	validation-rmse:5.31112
# [38]	validation-rmse:5.30892
# [39]	validation-rmse:5.30638
# [40]	validation-rmse:5.30420
# [41]	validation-rmse:5.30145
# [42]	validation-rmse:5.29893
# [43]	validation-rmse:5.29739
# [44]	validation-rmse:5.29511
# [45]	validation-rmse:5.29397
# [46]	validation-rmse:5.29161
# [47]	validation-rmse:5.29127
# [48]	validation-rmse:5.29089
# [49]	validation-rmse:5.28898
# [50]	validation-rmse:5.28843
# [51]	validation-rmse:5.28722
# [52]	validation-rmse:5.28678
# [53]	validation-rmse:5.28582
# [54]	validation-rmse:5.28557
# [55]	validation-rmse:5.28533
# [56]	validation-rmse:5.28389
# [57]	validation-rmse:5.28326
# [58]	validation-rmse:5.28320
# [59]	validation-rmse:5.28239
# [60]	validation-rmse:5.28236
# [61]	validation-rmse:5.28142
# [62]	validation-rmse:5.28152
# [63]	validation-rmse:5.28074
# [64]	validation-rmse:5.28035
# [65]	validation-rmse:5.28034
# [66]	validation-rmse:5.27852
# [67]	validation-rmse:5.27822
# [68]	validation-rmse:5.27644
# [69]	validation-rmse:5.27609
# [70]	validation-rmse:5.27603
# [71]	validation-rmse:5.27456
# [72]	validation-rmse:5.27453
# [73]	validation-rmse:5.27429
# [74]	validation-rmse:5.27315
# [75]	validation-rmse:5.27296
# [76]	validation-rmse:5.27215
# [77]	validation-rmse:5.27167
# [78]	validation-rmse:5.27179
# [79]	validation-rmse:5.27077
# [80]	validation-rmse:5.27073
# [81]	validation-rmse:5.27060
# [82]	validation-rmse:5.27010
# [83]	validation-rmse:5.26995
# [84]	validation-rmse:5.26929
# [85]	validation-rmse:5.26909
# [86]	validation-rmse:5.26871
# [87]	validation-rmse:5.26870
# [88]	validation-rmse:5.26882
# [89]	validation-rmse:5.26846
# [90]	validation-rmse:5.26793
# [91]	validation-rmse:5.26720
# [92]	validation-rmse:5.26695
# [93]	validation-rmse:5.26703
# [94]	validation-rmse:5.26644
# [95]	validation-rmse:5.26649
# [96]	validation-rmse:5.26588
# [97]	validation-rmse:5.26564
# [98]	validation-rmse:5.26582
# [99]	validation-rmse:5.26506
# [100]	validation-rmse:5.26501
# [101]	validation-rmse:5.26500
# [102]	validation-rmse:5.26473
# [103]	validation-rmse:5.26459
# [104]	validation-rmse:5.26407
# [105]	validation-rmse:5.26400
# [106]	validation-rmse:5.26372
# [107]	validation-rmse:5.26365
# [108]	validation-rmse:5.26356
# [109]	validation-rmse:5.26319
# [110]	validation-rmse:5.26328
# [111]	validation-rmse:5.26307
# [112]	validation-rmse:5.26286
# [113]	validation-rmse:5.26242
# [114]	validation-rmse:5.26228
# [115]	validation-rmse:5.26223
# [116]	validation-rmse:5.26191
# [117]	validation-rmse:5.26169
# [118]	validation-rmse:5.26170
# [119]	validation-rmse:5.26118
# [120]	validation-rmse:5.26138
# [121]	validation-rmse:5.26126
# [122]	validation-rmse:5.26122
# [123]	validation-rmse:5.26131
# [124]	validation-rmse:5.26141
# [125]	validation-rmse:5.26131
# [126]	validation-rmse:5.26143
# [127]	validation-rmse:5.26037
# [128]	validation-rmse:5.26039
# [129]	validation-rmse:5.26011
# [130]	validation-rmse:5.26009
# [131]	validation-rmse:5.26010
# [132]	validation-rmse:5.25969
# [133]	validation-rmse:5.25972
# [134]	validation-rmse:5.25923
# [135]	validation-rmse:5.25915
# [136]	validation-rmse:5.25920
# [137]	validation-rmse:5.25900
# [138]	validation-rmse:5.25869
# [139]	validation-rmse:5.25880
# [140]	validation-rmse:5.25851
# [141]	validation-rmse:5.25826
# [142]	validation-rmse:5.25809
# [143]	validation-rmse:5.25818
# [144]	validation-rmse:5.25812
# [145]	validation-rmse:5.25800
# [146]	validation-rmse:5.25749
# [147]	validation-rmse:5.25759
# [148]	validation-rmse:5.25725
# [149]	validation-rmse:5.25716
# [150]	validation-rmse:5.25699
# [151]	validation-rmse:5.25683
# [152]	validation-rmse:5.25686
# [153]	validation-rmse:5.25638
# [154]	validation-rmse:5.25637
# [155]	validation-rmse:5.25639
# [156]	validation-rmse:5.25616
# [157]	validation-rmse:5.25544
# [158]	validation-rmse:5.25561
# [159]	validation-rmse:5.25476
# [160]	validation-rmse:5.25453
# [161]	validation-rmse:5.25454
# [162]	validation-rmse:5.25394
# [163]	validation-rmse:5.25390
# [164]	validation-rmse:5.25372
# [165]	validation-rmse:5.25308
# [166]	validation-rmse:5.25312
# [167]	validation-rmse:5.25321
# [168]	validation-rmse:5.25281
# [169]	validation-rmse:5.25260
# [170]	validation-rmse:5.25250
# [171]	validation-rmse:5.25209
# [172]	validation-rmse:5.25208
# [173]	validation-rmse:5.25210
# [174]	validation-rmse:5.25190
# [175]	validation-rmse:5.25208
# [176]	validation-rmse:5.25156
# [177]	validation-rmse:5.25142
# [178]	validation-rmse:5.25144
# [179]	validation-rmse:5.25109
# [180]	validation-rmse:5.25104
# [181]	validation-rmse:5.25127
# [182]	validation-rmse:5.25092
# [183]	validation-rmse:5.25089
# [184]	validation-rmse:5.25119
# [185]	validation-rmse:5.25083
# [186]	validation-rmse:5.25066
# [187]	validation-rmse:5.25083
# [188]	validation-rmse:5.25051
# [189]	validation-rmse:5.25041
# [190]	validation-rmse:5.25037
# [191]	validation-rmse:5.25012
# [192]	validation-rmse:5.25024
# [193]	validation-rmse:5.24990
# [194]	validation-rmse:5.24983
# [195]	validation-rmse:5.24993
# [196]	validation-rmse:5.24971
# [197]	validation-rmse:5.24971
# [198]	validation-rmse:5.24970
# [199]	validation-rmse:5.24947
# [200]	validation-rmse:5.24944
# [201]	validation-rmse:5.24932
# [202]	validation-rmse:5.24934
# [203]	validation-rmse:5.24919
# [204]	validation-rmse:5.24926
# [205]	validation-rmse:5.24944
# [206]	validation-rmse:5.24907
# [207]	validation-rmse:5.24906
# [208]	validation-rmse:5.24888
# [209]	validation-rmse:5.24882
# [210]	validation-rmse:5.24883
# [211]	validation-rmse:5.24874
# [212]	validation-rmse:5.24871
# [213]	validation-rmse:5.24900
# [214]	validation-rmse:5.24874
# [215]	validation-rmse:5.24874
# [216]	validation-rmse:5.24843
# [217]	validation-rmse:5.24857
# [218]	validation-rmse:5.24859
# [219]	validation-rmse:5.24833
# [220]	validation-rmse:5.24837
# [221]	validation-rmse:5.24800
# [222]	validation-rmse:5.24791
# [223]	validation-rmse:5.24784
# [224]	validation-rmse:5.24782
# [225]	validation-rmse:5.24793
# [226]	validation-rmse:5.24788
# [227]	validation-rmse:5.24757
# [228]	validation-rmse:5.24763
# [229]	validation-rmse:5.24772
# [230]	validation-rmse:5.24751
# [231]	validation-rmse:5.24762
# [232]	validation-rmse:5.24759
# [233]	validation-rmse:5.24760
# [234]	validation-rmse:5.24760
# [235]	validation-rmse:5.24764
# [236]	validation-rmse:5.24763
# [237]	validation-rmse:5.24736
# [238]	validation-rmse:5.24732
# [239]	validation-rmse:5.24731
# [240]	validation-rmse:5.24727
# [241]	validation-rmse:5.24731
# [242]	validation-rmse:5.24707
# [243]	validation-rmse:5.24729
# [244]	validation-rmse:5.24732
# [245]	validation-rmse:5.24725
# [246]	validation-rmse:5.24717
# [247]	validation-rmse:5.24701
# [248]	validation-rmse:5.24712
# [249]	validation-rmse:5.24688
# [250]	validation-rmse:5.24674
# [251]	validation-rmse:5.24669
# [252]	validation-rmse:5.24682
# [253]	validation-rmse:5.24659
# [254]	validation-rmse:5.24657
# [255]	validation-rmse:5.24649
# [256]	validation-rmse:5.24637
# [257]	validation-rmse:5.24651
# [258]	validation-rmse:5.24656
# [259]	validation-rmse:5.24638
# [260]	validation-rmse:5.24617
# [261]	validation-rmse:5.24617
# [262]	validation-rmse:5.24616
# [263]	validation-rmse:5.24619
# [264]	validation-rmse:5.24614
# [265]	validation-rmse:5.24623
# [266]	validation-rmse:5.24628
# [267]	validation-rmse:5.24589
# [268]	validation-rmse:5.24587
# [269]	validation-rmse:5.24548
# [270]	validation-rmse:5.24566
# [271]	validation-rmse:5.24565
# [272]	validation-rmse:5.24556
# [273]	validation-rmse:5.24562
# [274]	validation-rmse:5.24574
# [275]	validation-rmse:5.24555
# [276]	validation-rmse:5.24528
# [277]	validation-rmse:5.24538
# [278]	validation-rmse:5.24543
# [279]	validation-rmse:5.24542
# [280]	validation-rmse:5.24558
# [281]	validation-rmse:5.24529
# [282]	validation-rmse:5.24527
# [283]	validation-rmse:5.24514
# [284]	validation-rmse:5.24493
# [285]	validation-rmse:5.24494
# [286]	validation-rmse:5.24480
# [287]	validation-rmse:5.24509
# [288]	validation-rmse:5.24516
# [289]	validation-rmse:5.24486
# [290]	validation-rmse:5.24490
# [291]	validation-rmse:5.24476
# [292]	validation-rmse:5.24482
# [293]	validation-rmse:5.24480
# [294]	validation-rmse:5.24484
# [295]	validation-rmse:5.24473
# [296]	validation-rmse:5.24471
# [297]	validation-rmse:5.24467
# [298]	validation-rmse:5.24471
# [299]	validation-rmse:5.24484
# [300]	validation-rmse:5.24462
# [301]	validation-rmse:5.24476
# [302]	validation-rmse:5.24472
# [303]	validation-rmse:5.24464
# [304]	validation-rmse:5.24464
# [305]	validation-rmse:5.24460
# [306]	validation-rmse:5.24465
# [307]	validation-rmse:5.24442
# [308]	validation-rmse:5.24438
# [309]	validation-rmse:5.24425
# [310]	validation-rmse:5.24419
# [311]	validation-rmse:5.24407
# [312]	validation-rmse:5.24412
# [313]	validation-rmse:5.24425
# [314]	validation-rmse:5.24419
# [315]	validation-rmse:5.24421
# [316]	validation-rmse:5.24416
# [317]	validation-rmse:5.24421
# [318]	validation-rmse:5.24416
# [319]	validation-rmse:5.24411
# [320]	validation-rmse:5.24409
# [321]	validation-rmse:5.24412
# [322]	validation-rmse:5.24372
# [323]	validation-rmse:5.24381
# [324]	validation-rmse:5.24379
# [325]	validation-rmse:5.24395
# [326]	validation-rmse:5.24406
# [327]	validation-rmse:5.24411
# [328]	validation-rmse:5.24420
# [329]	validation-rmse:5.24401
# [330]	validation-rmse:5.24396
# [331]	validation-rmse:5.24381
# [332]	validation-rmse:5.24386
# [333]	validation-rmse:5.24359
# [334]	validation-rmse:5.24368
# [335]	validation-rmse:5.24348
# [336]	validation-rmse:5.24338
# [337]	validation-rmse:5.24350
# [338]	validation-rmse:5.24351
# [339]	validation-rmse:5.24357
# [340]	validation-rmse:5.24344
# [341]	validation-rmse:5.24332
# [342]	validation-rmse:5.24317
# [343]	validation-rmse:5.24331
# [344]	validation-rmse:5.24317
# [345]	validation-rmse:5.24318
# [346]	validation-rmse:5.24306
# [347]	validation-rmse:5.24303
# [348]	validation-rmse:5.24314
# [349]	validation-rmse:5.24291
# [350]	validation-rmse:5.24307
# [351]	validation-rmse:5.24304
# [352]	validation-rmse:5.24303
# [353]	validation-rmse:5.24281
# [354]	validation-rmse:5.24289
# [355]	validation-rmse:5.24273
# [356]	validation-rmse:5.24263
# [357]	validation-rmse:5.24250
# [358]	validation-rmse:5.24245
# [359]	validation-rmse:5.24232
# [360]	validation-rmse:5.24227
# [361]	validation-rmse:5.24220
# [362]	validation-rmse:5.24223
# [363]	validation-rmse:5.24205
# [364]	validation-rmse:5.24216
# [365]	validation-rmse:5.24212
# [366]	validation-rmse:5.24217
# [367]	validation-rmse:5.24232
# [368]	validation-rmse:5.24215
# [369]	validation-rmse:5.24227
# [370]	validation-rmse:5.24228
# [371]	validation-rmse:5.24232
# [372]	validation-rmse:5.24234
# [373]	validation-rmse:5.24239
# [374]	validation-rmse:5.24237
# [375]	validation-rmse:5.24217
# [376]	validation-rmse:5.24228
# [377]	validation-rmse:5.24228
# [378]	validation-rmse:5.24215
# [379]	validation-rmse:5.24217
# [380]	validation-rmse:5.24217
# [381]	validation-rmse:5.24218
# [382]	validation-rmse:5.24205
# [383]	validation-rmse:5.24202
# [384]	validation-rmse:5.24213
# [385]	validation-rmse:5.24207
# [386]	validation-rmse:5.24200
# [387]	validation-rmse:5.24199
# [388]	validation-rmse:5.24208
# [389]	validation-rmse:5.24226
# [390]	validation-rmse:5.24208
# [391]	validation-rmse:5.24175
# [392]	validation-rmse:5.24181
# [393]	validation-rmse:5.24184
# [394]	validation-rmse:5.24173
# [395]	validation-rmse:5.24177
# [396]	validation-rmse:5.24153
# [397]	validation-rmse:5.24162
# [398]	validation-rmse:5.24154
# [399]	validation-rmse:5.24162
# [400]	validation-rmse:5.24144
# [401]	validation-rmse:5.24143
# [402]	validation-rmse:5.24128
# [403]	validation-rmse:5.24123
# [404]	validation-rmse:5.24119
# [405]	validation-rmse:5.24136
# [406]	validation-rmse:5.24143
# [407]	validation-rmse:5.24134
# [408]	validation-rmse:5.24139
# [409]	validation-rmse:5.24117
# [410]	validation-rmse:5.24137
# [411]	validation-rmse:5.24122
# [412]	validation-rmse:5.24129
# [413]	validation-rmse:5.24123
# [414]	validation-rmse:5.24126
# [415]	validation-rmse:5.24130
# [416]	validation-rmse:5.24133
# [417]	validation-rmse:5.24117
# [418]	validation-rmse:5.24117
# [419]	validation-rmse:5.24115
# [420]	validation-rmse:5.24122
# [421]	validation-rmse:5.24109
# [422]	validation-rmse:5.24111
# [423]	validation-rmse:5.24105
# [424]	validation-rmse:5.24111
# [425]	validation-rmse:5.24117
# [426]	validation-rmse:5.24099
# [427]	validation-rmse:5.24104
# [428]	validation-rmse:5.24087
# [429]	validation-rmse:5.24101
# [430]	validation-rmse:5.24098
# [431]	validation-rmse:5.24099
# [432]	validation-rmse:5.24090
# [433]	validation-rmse:5.24099
# [434]	validation-rmse:5.24089
# [435]	validation-rmse:5.24090
# [436]	validation-rmse:5.24089
# [437]	validation-rmse:5.24105
# [438]	validation-rmse:5.24102
# [439]	validation-rmse:5.24105
# [440]	validation-rmse:5.24100
# [441]	validation-rmse:5.24097
# [442]	validation-rmse:5.24090
# [443]	validation-rmse:5.24108
# [444]	validation-rmse:5.24086
# [445]	validation-rmse:5.24096
# [446]	validation-rmse:5.24091
# [447]	validation-rmse:5.24087
# [448]	validation-rmse:5.24086
# [449]	validation-rmse:5.24096
# [450]	validation-rmse:5.24096
# [451]	validation-rmse:5.24102
# [452]	validation-rmse:5.24106
# [453]	validation-rmse:5.24109
# [454]	validation-rmse:5.24096
# [455]	validation-rmse:5.24113
# [456]	validation-rmse:5.24096
# [457]	validation-rmse:5.24098
# [458]	validation-rmse:5.24105
# [459]	validation-rmse:5.24107
# [460]	validation-rmse:5.24099
# [461]	validation-rmse:5.24105
# [462]	validation-rmse:5.24078
# [463]	validation-rmse:5.24076
# [464]	validation-rmse:5.24070
# [465]	validation-rmse:5.24084
# [466]	validation-rmse:5.24093
# [467]	validation-rmse:5.24093
# [468]	validation-rmse:5.24081
# [469]	validation-rmse:5.24085
# [470]	validation-rmse:5.24095
# [471]	validation-rmse:5.24095
# [472]	validation-rmse:5.24085
# [473]	validation-rmse:5.24094
# [474]	validation-rmse:5.24101
# [475]	validation-rmse:5.24098
# [476]	validation-rmse:5.24101
# [477]	validation-rmse:5.24089
# [478]	validation-rmse:5.24095
# [479]	validation-rmse:5.24081
# [480]	validation-rmse:5.24090
# [481]	validation-rmse:5.24092
# [482]	validation-rmse:5.24094
# [483]	validation-rmse:5.24081
# [484]	validation-rmse:5.24093
# [485]	validation-rmse:5.24092
# [486]	validation-rmse:5.24103
# [487]	validation-rmse:5.24092
# [488]	validation-rmse:5.24103
# [489]	validation-rmse:5.24113
# [490]	validation-rmse:5.24108
# [491]	validation-rmse:5.24100
# [492]	validation-rmse:5.24116
# [493]	validation-rmse:5.24105
# [494]	validation-rmse:5.24109
# [495]	validation-rmse:5.24110
# [496]	validation-rmse:5.24120
# [497]	validation-rmse:5.24109
# [498]	validation-rmse:5.24109
# [499]	validation-rmse:5.24112
# [500]	validation-rmse:5.24112
# [501]	validation-rmse:5.24102
# [502]	validation-rmse:5.24116
# [503]	validation-rmse:5.24114
# [504]	validation-rmse:5.24121
# [505]	validation-rmse:5.24115
# [506]	validation-rmse:5.24112
# [507]	validation-rmse:5.24116
# [508]	validation-rmse:5.24115
# [509]	validation-rmse:5.24117
# [510]	validation-rmse:5.24106
# [511]	validation-rmse:5.24102
# [512]	validation-rmse:5.24091
# [513]	validation-rmse:5.24106
#   2%|▏         | 1/50 [02:03<1:40:45, 123.39s/trial, best loss: 5.2411049159803875]
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [11:37:50] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.25517
# [1]	validation-rmse:7.43436
# [2]	validation-rmse:6.81593
# [3]	validation-rmse:6.35783
# [4]	validation-rmse:6.02007
# [5]	validation-rmse:5.77782
# [6]	validation-rmse:5.60235
# [7]	validation-rmse:5.47707
# [8]	validation-rmse:5.38814
# [9]	validation-rmse:5.32723
# [10]	validation-rmse:5.28184
# [11]	validation-rmse:5.25049
# [12]	validation-rmse:5.22854
# [13]	validation-rmse:5.21158
# [14]	validation-rmse:5.20038
# [15]	validation-rmse:5.19093
# [16]	validation-rmse:5.18376
# [17]	validation-rmse:5.17891
# [18]	validation-rmse:5.17329
# [19]	validation-rmse:5.16946
# [20]	validation-rmse:5.16558
# [21]	validation-rmse:5.16413
# [22]	validation-rmse:5.16291
# [23]	validation-rmse:5.16203
# [24]	validation-rmse:5.16156
# [25]	validation-rmse:5.15969
# [26]	validation-rmse:5.15873
# [27]	validation-rmse:5.15803
# [28]	validation-rmse:5.15860
# [29]	validation-rmse:5.15724
# [30]	validation-rmse:5.15543
# [31]	validation-rmse:5.15536
# [32]	validation-rmse:5.15467
# [33]	validation-rmse:5.15436
# [34]	validation-rmse:5.15380
# [35]	validation-rmse:5.15349
# [36]	validation-rmse:5.15398
# [37]	validation-rmse:5.15368
# [38]	validation-rmse:5.15315
# [39]	validation-rmse:5.15240
# [40]	validation-rmse:5.15251
# [41]	validation-rmse:5.15119
# [42]	validation-rmse:5.15126
# [43]	validation-rmse:5.15102
# [44]	validation-rmse:5.15045
# [45]	validation-rmse:5.15000
# [46]	validation-rmse:5.14986
# [47]	validation-rmse:5.14979
# [48]	validation-rmse:5.14994
# [49]	validation-rmse:5.14977
# [50]	validation-rmse:5.14939
# [51]	validation-rmse:5.14938
# [52]	validation-rmse:5.14900
# [53]	validation-rmse:5.14888
# [54]	validation-rmse:5.14877
# [55]	validation-rmse:5.14787
# [56]	validation-rmse:5.14863
# [57]	validation-rmse:5.14896
# [58]	validation-rmse:5.14881
# [59]	validation-rmse:5.14839
# [60]	validation-rmse:5.14869
# [61]	validation-rmse:5.14873
# [62]	validation-rmse:5.14885
# [63]	validation-rmse:5.14870
# [64]	validation-rmse:5.14877
# [65]	validation-rmse:5.14833
# [66]	validation-rmse:5.14836
# [67]	validation-rmse:5.14856
# [68]	validation-rmse:5.14717
# [69]	validation-rmse:5.14760
# [70]	validation-rmse:5.14777
# [71]	validation-rmse:5.14765
# [72]	validation-rmse:5.14807
# [73]	validation-rmse:5.14659
# [74]	validation-rmse:5.14673
# [75]	validation-rmse:5.14691
# [76]	validation-rmse:5.14705
# [77]	validation-rmse:5.14713
# [78]	validation-rmse:5.14689
# [79]	validation-rmse:5.14692
# [80]	validation-rmse:5.14638
# [81]	validation-rmse:5.14640
# [82]	validation-rmse:5.14618
# [83]	validation-rmse:5.14626
# [84]	validation-rmse:5.14606
# [85]	validation-rmse:5.14602
# [86]	validation-rmse:5.14593
# [87]	validation-rmse:5.14599
# [88]	validation-rmse:5.14516
# [89]	validation-rmse:5.14514
# [90]	validation-rmse:5.14422
# [91]	validation-rmse:5.14410
# [92]	validation-rmse:5.14411
# [93]	validation-rmse:5.14441
# [94]	validation-rmse:5.14338
# [95]	validation-rmse:5.14303
# [96]	validation-rmse:5.14226
# [97]	validation-rmse:5.14193
# [98]	validation-rmse:5.14183
# [99]	validation-rmse:5.14139
# [100]	validation-rmse:5.14095
# [101]	validation-rmse:5.14149
# [102]	validation-rmse:5.14098
# [103]	validation-rmse:5.14115
# [104]	validation-rmse:5.14072
# [105]	validation-rmse:5.14045
# [106]	validation-rmse:5.14018
# [107]	validation-rmse:5.13971
# [108]	validation-rmse:5.13935
# [109]	validation-rmse:5.13927
# [110]	validation-rmse:5.13910
# [111]	validation-rmse:5.13852
# [112]	validation-rmse:5.13811
# [113]	validation-rmse:5.13782
# [114]	validation-rmse:5.13818
# [115]	validation-rmse:5.13792
# [116]	validation-rmse:5.13766
# [117]	validation-rmse:5.13782
# [118]	validation-rmse:5.13749
# [119]	validation-rmse:5.13748
# [120]	validation-rmse:5.13710
# [121]	validation-rmse:5.13698
# [122]	validation-rmse:5.13694
# [123]	validation-rmse:5.13670
# [124]	validation-rmse:5.13668
# [125]	validation-rmse:5.13647
# [126]	validation-rmse:5.13633
# [127]	validation-rmse:5.13615
# [128]	validation-rmse:5.13587
# [129]	validation-rmse:5.13586
# [130]	validation-rmse:5.13634
# [131]	validation-rmse:5.13610
# [132]	validation-rmse:5.13600
# [133]	validation-rmse:5.13594
# [134]	validation-rmse:5.13576
# [135]	validation-rmse:5.13564
# [136]	validation-rmse:5.13577
# [137]	validation-rmse:5.13531
# [138]	validation-rmse:5.13528
# [139]	validation-rmse:5.13529
# [140]	validation-rmse:5.13516
# [141]	validation-rmse:5.13520
# [142]	validation-rmse:5.13498
# [143]	validation-rmse:5.13526
# [144]	validation-rmse:5.13509
# [145]	validation-rmse:5.13521
# [146]	validation-rmse:5.13540
# [147]	validation-rmse:5.13574
# [148]	validation-rmse:5.13560
# [149]	validation-rmse:5.13563
# [150]	validation-rmse:5.13556
# [151]	validation-rmse:5.13585
# [152]	validation-rmse:5.13548
# [153]	validation-rmse:5.13545
# [154]	validation-rmse:5.13551
# [155]	validation-rmse:5.13546
# [156]	validation-rmse:5.13537
# [157]	validation-rmse:5.13498
# [158]	validation-rmse:5.13514
# [159]	validation-rmse:5.13488
# [160]	validation-rmse:5.13499
# [161]	validation-rmse:5.13499
# [162]	validation-rmse:5.13499
# [163]	validation-rmse:5.13516
# [164]	validation-rmse:5.13537
# [165]	validation-rmse:5.13579
# [166]	validation-rmse:5.13572
# [167]	validation-rmse:5.13569
# [168]	validation-rmse:5.13586
# [169]	validation-rmse:5.13586
# [170]	validation-rmse:5.13590
# [171]	validation-rmse:5.13594
# [172]	validation-rmse:5.13593
# [173]	validation-rmse:5.13589
# [174]	validation-rmse:5.13657
# [175]	validation-rmse:5.13657
# [176]	validation-rmse:5.13654
# [177]	validation-rmse:5.13655
# [178]	validation-rmse:5.13650
# [179]	validation-rmse:5.13669
# [180]	validation-rmse:5.13671
# [181]	validation-rmse:5.13673
# [182]	validation-rmse:5.13676
# [183]	validation-rmse:5.13681
# [184]	validation-rmse:5.13726
# [185]	validation-rmse:5.13750
# [186]	validation-rmse:5.13751
# [187]	validation-rmse:5.13724
# [188]	validation-rmse:5.13731
# [189]	validation-rmse:5.13755
# [190]	validation-rmse:5.13767
# [191]	validation-rmse:5.13777
# [192]	validation-rmse:5.13774
# [193]	validation-rmse:5.13801
# [194]	validation-rmse:5.13774
# [195]	validation-rmse:5.13802
# [196]	validation-rmse:5.13801
# [197]	validation-rmse:5.13806
# [198]	validation-rmse:5.13806
# [199]	validation-rmse:5.13804
# [200]	validation-rmse:5.13814
# [201]	validation-rmse:5.13832
# [202]	validation-rmse:5.13853
# [203]	validation-rmse:5.13839
# [204]	validation-rmse:5.13840
# [205]	validation-rmse:5.13869
# [206]	validation-rmse:5.13874
# [207]	validation-rmse:5.13896
# [208]	validation-rmse:5.13910
#   4%|▍         | 2/50 [03:02<1:08:19, 85.40s/trial, best loss: 5.138534068751411]
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [11:38:49] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.17513
# [1]	validation-rmse:7.33599
# [2]	validation-rmse:6.73746
# [3]	validation-rmse:6.31013
# [4]	validation-rmse:6.01384
# [5]	validation-rmse:5.80466
# ...
# [7]	validation-rmse:5.33940
# [8]	validation-rmse:5.29346
# [9]	validation-rmse:5.26351
# [10]	validation-rmse:5.24350
# [11]	validation-rmse:5.23107
# [12]	validation-rmse:5.21479
# [13]	validation-rmse:5.20886
# [14]	validation-rmse:5.20450
# [15]	validation-rmse:5.19934
# [16]	validation-rmse:5.19738
# [17]	validation-rmse:5.19744
# [18]	validation-rmse:5.19590
# [19]	validation-rmse:5.19531
# [20]	validation-rmse:5.19404
# [21]	validation-rmse:5.19294
# [22]	validation-rmse:5.19186
# [23]	validation-rmse:5.18967
# [24]	validation-rmse:5.18857
# [25]	validation-rmse:5.18659
# [26]	validation-rmse:5.18511
# [27]	validation-rmse:5.18327
# [28]	validation-rmse:5.18222
# [29]	validation-rmse:5.18093
# [30]	validation-rmse:5.18051
# [31]	validation-rmse:5.17988
# [32]	validation-rmse:5.17887
# [33]	validation-rmse:5.17846
# [34]	validation-rmse:5.17684
# [35]	validation-rmse:5.17647
# [36]	validation-rmse:5.17576
# [37]	validation-rmse:5.17557
# [38]	validation-rmse:5.17544
# [39]	validation-rmse:5.17436
# [40]	validation-rmse:5.17445
# [41]	validation-rmse:5.17275
# [42]	validation-rmse:5.17254
# [43]	validation-rmse:5.17186
# [44]	validation-rmse:5.17185
# [45]	validation-rmse:5.17117
# [46]	validation-rmse:5.17107
# [47]	validation-rmse:5.17026
# [48]	validation-rmse:5.16920
# [49]	validation-rmse:5.16844
# [50]	validation-rmse:5.16812
# [51]	validation-rmse:5.16749
# [52]	validation-rmse:5.16695
# [53]	validation-rmse:5.16610
# [54]	validation-rmse:5.16624
# [55]	validation-rmse:5.16548
# [56]	validation-rmse:5.16528
# [57]	validation-rmse:5.16552
# [58]	validation-rmse:5.16551
# [59]	validation-rmse:5.16486
# [60]	validation-rmse:5.16556
# [61]	validation-rmse:5.16234
# [62]	validation-rmse:5.16181
# [63]	validation-rmse:5.16151
# [64]	validation-rmse:5.16102
# [65]	validation-rmse:5.16182
# [66]	validation-rmse:5.16138
# [67]	validation-rmse:5.16166
# [68]	validation-rmse:5.15939
# [69]	validation-rmse:5.15929
# [70]	validation-rmse:5.15880
# [71]	validation-rmse:5.15773
# [72]	validation-rmse:5.15757
# [73]	validation-rmse:5.15785
# [74]	validation-rmse:5.15730
# [75]	validation-rmse:5.15741
# [76]	validation-rmse:5.15774
# [77]	validation-rmse:5.15790
# [78]	validation-rmse:5.15776
# [79]	validation-rmse:5.15846
# [80]	validation-rmse:5.15822
# [81]	validation-rmse:5.15835
# [82]	validation-rmse:5.15732
# [83]	validation-rmse:5.15747
# [84]	validation-rmse:5.15719
# [85]	validation-rmse:5.15744
# [86]	validation-rmse:5.15542
# [87]	validation-rmse:5.15503
# [88]	validation-rmse:5.15461
# [89]	validation-rmse:5.15442
# [90]	validation-rmse:5.15378
# [91]	validation-rmse:5.15425
# [92]	validation-rmse:5.15474
# [93]	validation-rmse:5.15249
# [94]	validation-rmse:5.15133
# [95]	validation-rmse:5.15060
# [96]	validation-rmse:5.15045
# [97]	validation-rmse:5.15019
# [98]	validation-rmse:5.14980
# [99]	validation-rmse:5.14987
# [100]	validation-rmse:5.14995
# [101]	validation-rmse:5.15025
# [102]	validation-rmse:5.15049
# [103]	validation-rmse:5.14849
# [104]	validation-rmse:5.14830
# [105]	validation-rmse:5.14798
# [106]	validation-rmse:5.14836
# [107]	validation-rmse:5.14846
# [108]	validation-rmse:5.14841
# [109]	validation-rmse:5.14779
# [110]	validation-rmse:5.14781
# [111]	validation-rmse:5.14781
# [112]	validation-rmse:5.14798
# [113]	validation-rmse:5.14665
# [114]	validation-rmse:5.14654
# [115]	validation-rmse:5.14689
# [116]	validation-rmse:5.14653
# [117]	validation-rmse:5.14655
# [118]	validation-rmse:5.14666
# [119]	validation-rmse:5.14665
# [120]	validation-rmse:5.14662
# [121]	validation-rmse:5.14735
# [122]	validation-rmse:5.14639
# [123]	validation-rmse:5.14625
# [124]	validation-rmse:5.14602
# [125]	validation-rmse:5.14508
# [126]	validation-rmse:5.14484
# [127]	validation-rmse:5.14482
# [128]	validation-rmse:5.14455
# [129]	validation-rmse:5.14246
# [130]	validation-rmse:5.14295
# [131]	validation-rmse:5.14299
# [132]	validation-rmse:5.14289
# [133]	validation-rmse:5.14318
# [134]	validation-rmse:5.14295
# [135]	validation-rmse:5.14319
# [136]	validation-rmse:5.14340
# [137]	validation-rmse:5.14293
# [138]	validation-rmse:5.14331
# [139]	validation-rmse:5.14300
# [140]	validation-rmse:5.14299
# [141]	validation-rmse:5.14291
# [142]	validation-rmse:5.14320
# [143]	validation-rmse:5.14337
# [144]	validation-rmse:5.14354
# [145]	validation-rmse:5.14256
# [146]	validation-rmse:5.14290
# [147]	validation-rmse:5.14301
# [148]	validation-rmse:5.14231
# [149]	validation-rmse:5.14224
# [150]	validation-rmse:5.14267
# [151]	validation-rmse:5.14294
# [152]	validation-rmse:5.14300
# [153]	validation-rmse:5.14254
# [154]	validation-rmse:5.14283
# [155]	validation-rmse:5.14276
# [156]	validation-rmse:5.14274
# [157]	validation-rmse:5.14258
# [158]	validation-rmse:5.14278
# [159]	validation-rmse:5.14268
# [160]	validation-rmse:5.14311
# [161]	validation-rmse:5.14345
# [162]	validation-rmse:5.14387
# [163]	validation-rmse:5.14413
# [164]	validation-rmse:5.14375
# [165]	validation-rmse:5.14384
# [166]	validation-rmse:5.14373
# [167]	validation-rmse:5.14402
# [168]	validation-rmse:5.14384
# [169]	validation-rmse:5.14407
# [170]	validation-rmse:5.14337
# [171]	validation-rmse:5.14391
# [172]	validation-rmse:5.14389
# [173]	validation-rmse:5.14455
# [174]	validation-rmse:5.14424
# [175]	validation-rmse:5.14447
# [176]	validation-rmse:5.14472
# [177]	validation-rmse:5.14488
# [178]	validation-rmse:5.14491
# [179]	validation-rmse:5.14493
# [180]	validation-rmse:5.14511
# [181]	validation-rmse:5.14514
# [182]	validation-rmse:5.14438
# [183]	validation-rmse:5.14448
# [184]	validation-rmse:5.14463
# [185]	validation-rmse:5.14385
# [186]	validation-rmse:5.14292
# [187]	validation-rmse:5.14304
# [188]	validation-rmse:5.14277
# [189]	validation-rmse:5.14316
# [190]	validation-rmse:5.14314
# [191]	validation-rmse:5.14366
# [192]	validation-rmse:5.14278
# [193]	validation-rmse:5.14346
# [194]	validation-rmse:5.14285
# [195]	validation-rmse:5.14272
# [196]	validation-rmse:5.14256
# [197]	validation-rmse:5.14311
# [198]	validation-rmse:5.14274
# 100%|██████████| 50/50 [52:55<00:00, 63.50s/trial, best loss: 5.116646591501965]
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.06273447100027489,
        'max_depth': 52,
        'min_child_weight': 3.372889853990348,
        'objective': 'reg:linear',
        'reg_alpha': 0.06919062960886975,
        'reg_lambda': 0.024791137697948,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [10:49:33] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.92920
# [1]	validation-rmse:8.56914
# [2]	validation-rmse:8.23995
# [3]	validation-rmse:7.93935
# [4]	validation-rmse:7.66533
# [5]	validation-rmse:7.41617
# [6]	validation-rmse:7.18995
# [7]	validation-rmse:6.98521
# [8]	validation-rmse:6.79965
# [9]	validation-rmse:6.63266
# [10]	validation-rmse:6.48169
# [11]	validation-rmse:6.34575
# [12]	validation-rmse:6.22383
# [13]	validation-rmse:6.11404
# [14]	validation-rmse:6.01495
# [15]	validation-rmse:5.92690
# [16]	validation-rmse:5.84817
# [17]	validation-rmse:5.77689
# [18]	validation-rmse:5.71396
# [19]	validation-rmse:5.65699
# [20]	validation-rmse:5.60614
# [21]	validation-rmse:5.56119
# [22]	validation-rmse:5.52026
# [23]	validation-rmse:5.48388
# [24]	validation-rmse:5.45155
# [25]	validation-rmse:5.42243
# [26]	validation-rmse:5.39671
# [27]	validation-rmse:5.37452
# [28]	validation-rmse:5.35457
# [29]	validation-rmse:5.33566
# [30]	validation-rmse:5.31984
# [31]	validation-rmse:5.30507
# [32]	validation-rmse:5.29177
# [33]	validation-rmse:5.28022
# [34]	validation-rmse:5.26983
# [35]	validation-rmse:5.25954
# [36]	validation-rmse:5.25089
# [37]	validation-rmse:5.24248
# [38]	validation-rmse:5.23606
# [39]	validation-rmse:5.22917
# [40]	validation-rmse:5.22390
# [41]	validation-rmse:5.21903
# [42]	validation-rmse:5.21427
# [43]	validation-rmse:5.21026
# [44]	validation-rmse:5.20584
# [45]	validation-rmse:5.20176
# [46]	validation-rmse:5.19927
# [47]	validation-rmse:5.19618
# [48]	validation-rmse:5.19400
# [49]	validation-rmse:5.19183
# [50]	validation-rmse:5.18975
# [51]	validation-rmse:5.18779
# [52]	validation-rmse:5.18600
# [53]	validation-rmse:5.18450
# [54]	validation-rmse:5.18282
# [55]	validation-rmse:5.18161
# [56]	validation-rmse:5.18058
# [57]	validation-rmse:5.17926
# [58]	validation-rmse:5.17806
# [59]	validation-rmse:5.17678
# [60]	validation-rmse:5.17602
# [61]	validation-rmse:5.17448
# [62]	validation-rmse:5.17342
# [63]	validation-rmse:5.17300
# [64]	validation-rmse:5.17240
# [65]	validation-rmse:5.17179
# [66]	validation-rmse:5.17155
# [67]	validation-rmse:5.17034
# [68]	validation-rmse:5.16971
# [69]	validation-rmse:5.16892
# [70]	validation-rmse:5.16863
# [71]	validation-rmse:5.16789
# [72]	validation-rmse:5.16725
# [73]	validation-rmse:5.16666
# [74]	validation-rmse:5.16502
# [75]	validation-rmse:5.16383
# [76]	validation-rmse:5.16367
# [77]	validation-rmse:5.16343
# [78]	validation-rmse:5.16290
# [79]	validation-rmse:5.16265
# [80]	validation-rmse:5.16210
# [81]	validation-rmse:5.16209
# [82]	validation-rmse:5.16207
# [83]	validation-rmse:5.16032
# [84]	validation-rmse:5.16033
# [85]	validation-rmse:5.15902
# [86]	validation-rmse:5.15856
# [87]	validation-rmse:5.15828
# [88]	validation-rmse:5.15757
# [89]	validation-rmse:5.15747
# [90]	validation-rmse:5.15669
# [91]	validation-rmse:5.15651
# [92]	validation-rmse:5.15563
# [93]	validation-rmse:5.15466
# [94]	validation-rmse:5.15438
# [95]	validation-rmse:5.15410
# [96]	validation-rmse:5.15420
# [97]	validation-rmse:5.15349
# [98]	validation-rmse:5.15267
# [99]	validation-rmse:5.15225
# [100]	validation-rmse:5.15212
# [101]	validation-rmse:5.15201
# [102]	validation-rmse:5.15175
# [103]	validation-rmse:5.15141
# [104]	validation-rmse:5.15106
# [105]	validation-rmse:5.15043
# [106]	validation-rmse:5.15012
# [107]	validation-rmse:5.15014
# [108]	validation-rmse:5.14988
# [109]	validation-rmse:5.14961
# [110]	validation-rmse:5.14953
# [111]	validation-rmse:5.14949
# [112]	validation-rmse:5.14928
# [113]	validation-rmse:5.14889
# [114]	validation-rmse:5.14859
# [115]	validation-rmse:5.14844
# [116]	validation-rmse:5.14810
# [117]	validation-rmse:5.14782
# [118]	validation-rmse:5.14764
# [119]	validation-rmse:5.14760
# [120]	validation-rmse:5.14755
# [121]	validation-rmse:5.14741
# [122]	validation-rmse:5.14745
# [123]	validation-rmse:5.14724
# [124]	validation-rmse:5.14701
# [125]	validation-rmse:5.14690
# [126]	validation-rmse:5.14652
# [127]	validation-rmse:5.14651
# [128]	validation-rmse:5.14645
# [129]	validation-rmse:5.14634
# [130]	validation-rmse:5.14630
# [131]	validation-rmse:5.14632
# [132]	validation-rmse:5.14607
# [133]	validation-rmse:5.14590
# [134]	validation-rmse:5.14575
# [135]	validation-rmse:5.14550
# [136]	validation-rmse:5.14542
# [137]	validation-rmse:5.14512
# [138]	validation-rmse:5.14497
# [139]	validation-rmse:5.14498
# [140]	validation-rmse:5.14486
# [141]	validation-rmse:5.14474
# [142]	validation-rmse:5.14476
# [143]	validation-rmse:5.14448
# [144]	validation-rmse:5.14420
# [145]	validation-rmse:5.14412
# [146]	validation-rmse:5.14406
# [147]	validation-rmse:5.14374
# [148]	validation-rmse:5.14363
# [149]	validation-rmse:5.14356
# [150]	validation-rmse:5.14352
# [151]	validation-rmse:5.14353
# [152]	validation-rmse:5.14335
# [153]	validation-rmse:5.14322
# [154]	validation-rmse:5.14328
# [155]	validation-rmse:5.14317
# [156]	validation-rmse:5.14303
# [157]	validation-rmse:5.14292
# [158]	validation-rmse:5.14272
# [159]	validation-rmse:5.14277
# [160]	validation-rmse:5.14270
# [161]	validation-rmse:5.14275
# [162]	validation-rmse:5.14271
# [163]	validation-rmse:5.14264
# [164]	validation-rmse:5.14251
# [165]	validation-rmse:5.14250
# [166]	validation-rmse:5.14235
# [167]	validation-rmse:5.14219
# [168]	validation-rmse:5.14214
# [169]	validation-rmse:5.14221
# [170]	validation-rmse:5.14193
# [171]	validation-rmse:5.14178
# [172]	validation-rmse:5.14147
# [173]	validation-rmse:5.14145
# [174]	validation-rmse:5.14166
# [175]	validation-rmse:5.14151
# [176]	validation-rmse:5.14159
# [177]	validation-rmse:5.14150
# [178]	validation-rmse:5.14142
# [179]	validation-rmse:5.14123
# [180]	validation-rmse:5.14113
# [181]	validation-rmse:5.14113
# [182]	validation-rmse:5.14102
# [183]	validation-rmse:5.14108
# [184]	validation-rmse:5.14074
# [185]	validation-rmse:5.14063
# [186]	validation-rmse:5.14061
# [187]	validation-rmse:5.14040
# [188]	validation-rmse:5.14040
# [189]	validation-rmse:5.14033
# [190]	validation-rmse:5.14040
# [191]	validation-rmse:5.14048
# [192]	validation-rmse:5.14048
# [193]	validation-rmse:5.14014
# [194]	validation-rmse:5.13996
# [195]	validation-rmse:5.13991
# [196]	validation-rmse:5.14009
# [197]	validation-rmse:5.14015
# [198]	validation-rmse:5.14001
# [199]	validation-rmse:5.13997
# [200]	validation-rmse:5.13973
# [201]	validation-rmse:5.13978
# [202]	validation-rmse:5.13963
# [203]	validation-rmse:5.13950
# [204]	validation-rmse:5.13935
# [205]	validation-rmse:5.13946
# [206]	validation-rmse:5.13935
# [207]	validation-rmse:5.13937
# [208]	validation-rmse:5.13924
# [209]	validation-rmse:5.13910
# [210]	validation-rmse:5.13922
# [211]	validation-rmse:5.13925
# [212]	validation-rmse:5.13917
# [213]	validation-rmse:5.13908
# [214]	validation-rmse:5.13891
# [215]	validation-rmse:5.13886
# [216]	validation-rmse:5.13879
# [217]	validation-rmse:5.13856
# [218]	validation-rmse:5.13859
# [219]	validation-rmse:5.13850
# [220]	validation-rmse:5.13840
# [221]	validation-rmse:5.13835
# [222]	validation-rmse:5.13859
# [223]	validation-rmse:5.13829
# [224]	validation-rmse:5.13827
# [225]	validation-rmse:5.13828
# [226]	validation-rmse:5.13823
# [227]	validation-rmse:5.13812
# [228]	validation-rmse:5.13814
# [229]	validation-rmse:5.13806
# [230]	validation-rmse:5.13803
# [231]	validation-rmse:5.13793
# [232]	validation-rmse:5.13779
# [233]	validation-rmse:5.13780
# [234]	validation-rmse:5.13763
# [235]	validation-rmse:5.13754
# [236]	validation-rmse:5.13749
# [237]	validation-rmse:5.13743
# [238]	validation-rmse:5.13709
# [239]	validation-rmse:5.13673
# [240]	validation-rmse:5.13649
# [241]	validation-rmse:5.13672
# [242]	validation-rmse:5.13657
# [243]	validation-rmse:5.13628
# [244]	validation-rmse:5.13626
# [245]	validation-rmse:5.13604
# [246]	validation-rmse:5.13589
# [247]	validation-rmse:5.13583
# [248]	validation-rmse:5.13597
# [249]	validation-rmse:5.13570
# [250]	validation-rmse:5.13555
# [251]	validation-rmse:5.13554
# [252]	validation-rmse:5.13558
# [253]	validation-rmse:5.13550
# [254]	validation-rmse:5.13571
# [255]	validation-rmse:5.13586
# [256]	validation-rmse:5.13583
# [257]	validation-rmse:5.13566
# [258]	validation-rmse:5.13593
# [259]	validation-rmse:5.13596
# [260]	validation-rmse:5.13571
# [261]	validation-rmse:5.13593
# [262]	validation-rmse:5.13585
# [263]	validation-rmse:5.13581
# [264]	validation-rmse:5.13600
# [265]	validation-rmse:5.13587
# [266]	validation-rmse:5.13606
# [267]	validation-rmse:5.13605
# [268]	validation-rmse:5.13586
# [269]	validation-rmse:5.13585
# [270]	validation-rmse:5.13590
# [271]	validation-rmse:5.13589
# [272]	validation-rmse:5.13581
# [273]	validation-rmse:5.13587
# [274]	validation-rmse:5.13574
# [275]	validation-rmse:5.13569
# [276]	validation-rmse:5.13558
# [277]	validation-rmse:5.13549
# [278]	validation-rmse:5.13573
# [279]	validation-rmse:5.13542
# [280]	validation-rmse:5.13539
# [281]	validation-rmse:5.13532
# [282]	validation-rmse:5.13490
# [283]	validation-rmse:5.13499
# [284]	validation-rmse:5.13447
# [285]	validation-rmse:5.13415
# [286]	validation-rmse:5.13408
# [287]	validation-rmse:5.13367
# [288]	validation-rmse:5.13353
# [289]	validation-rmse:5.13315
# [290]	validation-rmse:5.13306
# [291]	validation-rmse:5.13272
# [292]	validation-rmse:5.13263
# [293]	validation-rmse:5.13231
# [294]	validation-rmse:5.13231
# [295]	validation-rmse:5.13198
# [296]	validation-rmse:5.13190
# [297]	validation-rmse:5.13159
# [298]	validation-rmse:5.13161
# [299]	validation-rmse:5.13131
# [300]	validation-rmse:5.13117
# [301]	validation-rmse:5.13098
# [302]	validation-rmse:5.13097
# [303]	validation-rmse:5.13094
# [304]	validation-rmse:5.13066
# [305]	validation-rmse:5.13057
# [306]	validation-rmse:5.13028
# [307]	validation-rmse:5.13020
# [308]	validation-rmse:5.12992
# [309]	validation-rmse:5.12986
# [310]	validation-rmse:5.12956
# [311]	validation-rmse:5.12955
# [312]	validation-rmse:5.12944
# [313]	validation-rmse:5.12942
# [314]	validation-rmse:5.12964
# [315]	validation-rmse:5.12970
# [316]	validation-rmse:5.12930
# [317]	validation-rmse:5.12925
# [318]	validation-rmse:5.12899
# [319]	validation-rmse:5.12894
# [320]	validation-rmse:5.12866
# [321]	validation-rmse:5.12862
# [322]	validation-rmse:5.12857
# [323]	validation-rmse:5.12855
# [324]	validation-rmse:5.12838
# [325]	validation-rmse:5.12838
# [326]	validation-rmse:5.12845
# [327]	validation-rmse:5.12833
# [328]	validation-rmse:5.12840
# [329]	validation-rmse:5.12815
# [330]	validation-rmse:5.12807
# [331]	validation-rmse:5.12784
# [332]	validation-rmse:5.12769
# [333]	validation-rmse:5.12766
# [334]	validation-rmse:5.12771
# [335]	validation-rmse:5.12747
# [336]	validation-rmse:5.12746
# [337]	validation-rmse:5.12723
# [338]	validation-rmse:5.12723
# [339]	validation-rmse:5.12720
# [340]	validation-rmse:5.12712
# [341]	validation-rmse:5.12723
# [342]	validation-rmse:5.12708
# [343]	validation-rmse:5.12706
# [344]	validation-rmse:5.12681
# [345]	validation-rmse:5.12683
# [346]	validation-rmse:5.12686
# [347]	validation-rmse:5.12675
# [348]	validation-rmse:5.12668
# [349]	validation-rmse:5.12672
# [350]	validation-rmse:5.12644
# [351]	validation-rmse:5.12639
# [352]	validation-rmse:5.12621
# [353]	validation-rmse:5.12636
# [354]	validation-rmse:5.12628
# [355]	validation-rmse:5.12624
# [356]	validation-rmse:5.12613
# [357]	validation-rmse:5.12613
# [358]	validation-rmse:5.12622
# [359]	validation-rmse:5.12594
# [360]	validation-rmse:5.12592
# [361]	validation-rmse:5.12580
# [362]	validation-rmse:5.12582
# [363]	validation-rmse:5.12568
# [364]	validation-rmse:5.12568
# [365]	validation-rmse:5.12578
# [366]	validation-rmse:5.12570
# [367]	validation-rmse:5.12561
# [368]	validation-rmse:5.12525
# [369]	validation-rmse:5.12531
# [370]	validation-rmse:5.12519
# [371]	validation-rmse:5.12516
# [372]	validation-rmse:5.12515
# [373]	validation-rmse:5.12496
# [374]	validation-rmse:5.12494
# [375]	validation-rmse:5.12491
# [376]	validation-rmse:5.12488
# [377]	validation-rmse:5.12478
# [378]	validation-rmse:5.12463
# [379]	validation-rmse:5.12460
# [380]	validation-rmse:5.12434
# [381]	validation-rmse:5.12446
# [382]	validation-rmse:5.12427
# [383]	validation-rmse:5.12416
# [384]	validation-rmse:5.12403
# [385]	validation-rmse:5.12415
# [386]	validation-rmse:5.12427
# [387]	validation-rmse:5.12397
# [388]	validation-rmse:5.12409
# [389]	validation-rmse:5.12395
# [390]	validation-rmse:5.12399
# [391]	validation-rmse:5.12385
# [392]	validation-rmse:5.12384
# [393]	validation-rmse:5.12366
# [394]	validation-rmse:5.12362
# [395]	validation-rmse:5.12373
# [396]	validation-rmse:5.12361
# [397]	validation-rmse:5.12361
# [398]	validation-rmse:5.12350
# [399]	validation-rmse:5.12347
# [400]	validation-rmse:5.12357
# [401]	validation-rmse:5.12342
# [402]	validation-rmse:5.12323
# [403]	validation-rmse:5.12318
# [404]	validation-rmse:5.12304
# [405]	validation-rmse:5.12309
# [406]	validation-rmse:5.12296
# [407]	validation-rmse:5.12295
# [408]	validation-rmse:5.12307
# [409]	validation-rmse:5.12295
# [410]	validation-rmse:5.12287
# [411]	validation-rmse:5.12297
# [412]	validation-rmse:5.12275
# [413]	validation-rmse:5.12269
# [414]	validation-rmse:5.12263
# [415]	validation-rmse:5.12262
# [416]	validation-rmse:5.12260
# [417]	validation-rmse:5.12247
# [418]	validation-rmse:5.12249
# [419]	validation-rmse:5.12240
# [420]	validation-rmse:5.12234
# [421]	validation-rmse:5.12232
# [422]	validation-rmse:5.12231
# [423]	validation-rmse:5.12236
# [424]	validation-rmse:5.12230
# [425]	validation-rmse:5.12227
# [426]	validation-rmse:5.12215
# [427]	validation-rmse:5.12217
# [428]	validation-rmse:5.12215
# [429]	validation-rmse:5.12206
# [430]	validation-rmse:5.12210
# [431]	validation-rmse:5.12203
# [432]	validation-rmse:5.12206
# [433]	validation-rmse:5.12186
# [434]	validation-rmse:5.12180
# [435]	validation-rmse:5.12192
# [436]	validation-rmse:5.12177
# [437]	validation-rmse:5.12165
# [438]	validation-rmse:5.12170
# [439]	validation-rmse:5.12157
# [440]	validation-rmse:5.12159
# [441]	validation-rmse:5.12156
# [442]	validation-rmse:5.12151
# [443]	validation-rmse:5.12146
# [444]	validation-rmse:5.12131
# [445]	validation-rmse:5.12122
# [446]	validation-rmse:5.12118
# [447]	validation-rmse:5.12108
# [448]	validation-rmse:5.12108
# [449]	validation-rmse:5.12103
# [450]	validation-rmse:5.12101
# [451]	validation-rmse:5.12086
# [452]	validation-rmse:5.12084
# [453]	validation-rmse:5.12086
# [454]	validation-rmse:5.12095
# [455]	validation-rmse:5.12077
# [456]	validation-rmse:5.12079
# [457]	validation-rmse:5.12072
# [458]	validation-rmse:5.12071
# [459]	validation-rmse:5.12073
# [460]	validation-rmse:5.12073
# [461]	validation-rmse:5.12062
# [462]	validation-rmse:5.12058
# [463]	validation-rmse:5.12057
# [464]	validation-rmse:5.12073
# [465]	validation-rmse:5.12063
# [466]	validation-rmse:5.12064
# [467]	validation-rmse:5.12055
# [468]	validation-rmse:5.12050
# [469]	validation-rmse:5.12043
# [470]	validation-rmse:5.12037
# [471]	validation-rmse:5.12024
# [472]	validation-rmse:5.12000
# [473]	validation-rmse:5.11997
# [474]	validation-rmse:5.11984
# [475]	validation-rmse:5.11983
# [476]	validation-rmse:5.11977
# [477]	validation-rmse:5.11977
# [478]	validation-rmse:5.11976
# [479]	validation-rmse:5.11963
# [480]	validation-rmse:5.11957
# [481]	validation-rmse:5.11957
# [482]	validation-rmse:5.11956
# [483]	validation-rmse:5.11954
# [484]	validation-rmse:5.11950
# [485]	validation-rmse:5.11945
# [486]	validation-rmse:5.11941
# [487]	validation-rmse:5.11934
# [488]	validation-rmse:5.11927
# [489]	validation-rmse:5.11926
# [490]	validation-rmse:5.11926
# [491]	validation-rmse:5.11918
# [492]	validation-rmse:5.11925
# [493]	validation-rmse:5.11916
# [494]	validation-rmse:5.11918
# [495]	validation-rmse:5.11909
# [496]	validation-rmse:5.11909
# [497]	validation-rmse:5.11919
# [498]	validation-rmse:5.11928
# [499]	validation-rmse:5.11922
# [500]	validation-rmse:5.11922
# [501]	validation-rmse:5.11922
# [502]	validation-rmse:5.11913
# [503]	validation-rmse:5.11918
# [504]	validation-rmse:5.11910
# [505]	validation-rmse:5.11907
# [506]	validation-rmse:5.11901
# [507]	validation-rmse:5.11901
# [508]	validation-rmse:5.11896
# [509]	validation-rmse:5.11902
# [510]	validation-rmse:5.11908
# [511]	validation-rmse:5.11902
# [512]	validation-rmse:5.11897
# [513]	validation-rmse:5.11898
# [514]	validation-rmse:5.11901
# [515]	validation-rmse:5.11890
# [516]	validation-rmse:5.11886
# [517]	validation-rmse:5.11872
# [518]	validation-rmse:5.11872
# [519]	validation-rmse:5.11875
# [520]	validation-rmse:5.11866
# [521]	validation-rmse:5.11863
# [522]	validation-rmse:5.11857
# [523]	validation-rmse:5.11849
# [524]	validation-rmse:5.11848
# [525]	validation-rmse:5.11848
# [526]	validation-rmse:5.11861
# [527]	validation-rmse:5.11842
# [528]	validation-rmse:5.11841
# [529]	validation-rmse:5.11851
# [530]	validation-rmse:5.11841
# [531]	validation-rmse:5.11845
# [532]	validation-rmse:5.11836
# [533]	validation-rmse:5.11837
# [534]	validation-rmse:5.11831
# [535]	validation-rmse:5.11839
# [536]	validation-rmse:5.11836
# [537]	validation-rmse:5.11825
# [538]	validation-rmse:5.11818
# [539]	validation-rmse:5.11801
# [540]	validation-rmse:5.11804
# [541]	validation-rmse:5.11808
# [542]	validation-rmse:5.11808
# [543]	validation-rmse:5.11801
# [544]	validation-rmse:5.11796
# [545]	validation-rmse:5.11802
# [546]	validation-rmse:5.11798
# [547]	validation-rmse:5.11793
# [548]	validation-rmse:5.11803
# [549]	validation-rmse:5.11800
# [550]	validation-rmse:5.11798
# [551]	validation-rmse:5.11788
# [552]	validation-rmse:5.11796
# [553]	validation-rmse:5.11790
# [554]	validation-rmse:5.11791
# [555]	validation-rmse:5.11793
# [556]	validation-rmse:5.11786
# [557]	validation-rmse:5.11785
# [558]	validation-rmse:5.11784
# [559]	validation-rmse:5.11785
# [560]	validation-rmse:5.11782
# [561]	validation-rmse:5.11783
# [562]	validation-rmse:5.11783
# [563]	validation-rmse:5.11774
# [564]	validation-rmse:5.11781
# [565]	validation-rmse:5.11783
# [566]	validation-rmse:5.11786
# [567]	validation-rmse:5.11792
# [568]	validation-rmse:5.11791
# [569]	validation-rmse:5.11784
# [570]	validation-rmse:5.11782
# [571]	validation-rmse:5.11788
# [572]	validation-rmse:5.11782
# [573]	validation-rmse:5.11786
# [574]	validation-rmse:5.11778
# [575]	validation-rmse:5.11774
# [576]	validation-rmse:5.11774
# [577]	validation-rmse:5.11762
# [578]	validation-rmse:5.11767
# [579]	validation-rmse:5.11763
# [580]	validation-rmse:5.11755
# [581]	validation-rmse:5.11754
# [582]	validation-rmse:5.11759
# [583]	validation-rmse:5.11765
# [584]	validation-rmse:5.11764
# [585]	validation-rmse:5.11764
# [586]	validation-rmse:5.11751
# [587]	validation-rmse:5.11748
# [588]	validation-rmse:5.11742
# [589]	validation-rmse:5.11756
# [590]	validation-rmse:5.11748
# [591]	validation-rmse:5.11750
# [592]	validation-rmse:5.11753
# [593]	validation-rmse:5.11752
# [594]	validation-rmse:5.11750
# [595]	validation-rmse:5.11736
# [596]	validation-rmse:5.11733
# [597]	validation-rmse:5.11718
# [598]	validation-rmse:5.11727
# [599]	validation-rmse:5.11738
# [600]	validation-rmse:5.11731
# [601]	validation-rmse:5.11724
# [602]	validation-rmse:5.11722
# [603]	validation-rmse:5.11713
# [604]	validation-rmse:5.11709
# [605]	validation-rmse:5.11703
# [606]	validation-rmse:5.11700
# [607]	validation-rmse:5.11705
# [608]	validation-rmse:5.11722
# [609]	validation-rmse:5.11715
# [610]	validation-rmse:5.11711
# [611]	validation-rmse:5.11703
# [612]	validation-rmse:5.11709
# [613]	validation-rmse:5.11720
# [614]	validation-rmse:5.11716
# [615]	validation-rmse:5.11716
# [616]	validation-rmse:5.11714
# [617]	validation-rmse:5.11718
# [618]	validation-rmse:5.11721
# [619]	validation-rmse:5.11720
# [620]	validation-rmse:5.11720
# [621]	validation-rmse:5.11729
# [622]	validation-rmse:5.11716
# [623]	validation-rmse:5.11709
# [624]	validation-rmse:5.11714
# [625]	validation-rmse:5.11724
# [626]	validation-rmse:5.11722
# [627]	validation-rmse:5.11725
# [628]	validation-rmse:5.11697
# [629]	validation-rmse:5.11691
# [630]	validation-rmse:5.11673
# [631]	validation-rmse:5.11675
# [632]	validation-rmse:5.11665
# [633]	validation-rmse:5.11663
# [634]	validation-rmse:5.11666
# [635]	validation-rmse:5.11668
# [636]	validation-rmse:5.11672
# [637]	validation-rmse:5.11672
# [638]	validation-rmse:5.11670
# [639]	validation-rmse:5.11670
# [640]	validation-rmse:5.11677
# [641]	validation-rmse:5.11676
# [642]	validation-rmse:5.11676
# [643]	validation-rmse:5.11668
# [644]	validation-rmse:5.11659
# [645]	validation-rmse:5.11663
# [646]	validation-rmse:5.11666
# [647]	validation-rmse:5.11661
# [648]	validation-rmse:5.11667
# [649]	validation-rmse:5.11671
# [650]	validation-rmse:5.11671
# [651]	validation-rmse:5.11674
# [652]	validation-rmse:5.11677
# [653]	validation-rmse:5.11675
# [654]	validation-rmse:5.11671
# [655]	validation-rmse:5.11673
# [656]	validation-rmse:5.11688
# [657]	validation-rmse:5.11685
# [658]	validation-rmse:5.11677
# [659]	validation-rmse:5.11674
# [660]	validation-rmse:5.11660
# [661]	validation-rmse:5.11661
# [662]	validation-rmse:5.11676
# [663]	validation-rmse:5.11669
# [664]	validation-rmse:5.11674
# [665]	validation-rmse:5.11671
# [666]	validation-rmse:5.11667
# [667]	validation-rmse:5.11676
# [668]	validation-rmse:5.11677
# [669]	validation-rmse:5.11676
# [670]	validation-rmse:5.11671
# [671]	validation-rmse:5.11668
# [672]	validation-rmse:5.11665
# [673]	validation-rmse:5.11647
# [674]	validation-rmse:5.11637
# [675]	validation-rmse:5.11633
# [676]	validation-rmse:5.11634
# [677]	validation-rmse:5.11648
# [678]	validation-rmse:5.11662
# [679]	validation-rmse:5.11666
# [680]	validation-rmse:5.11662
# [681]	validation-rmse:5.11666
# [682]	validation-rmse:5.11673
# [683]	validation-rmse:5.11675
# [684]	validation-rmse:5.11675
# [685]	validation-rmse:5.11671
# [686]	validation-rmse:5.11668
# [687]	validation-rmse:5.11678
# [688]	validation-rmse:5.11666
# [689]	validation-rmse:5.11664
# [690]	validation-rmse:5.11660
# [691]	validation-rmse:5.11662
# [692]	validation-rmse:5.11662
# [693]	validation-rmse:5.11661
# [694]	validation-rmse:5.11669
# [695]	validation-rmse:5.11669
# [696]	validation-rmse:5.11670
# [697]	validation-rmse:5.11665
# [698]	validation-rmse:5.11666
# [699]	validation-rmse:5.11662
# [700]	validation-rmse:5.11667
# [701]	validation-rmse:5.11665
# [702]	validation-rmse:5.11671
# [703]	validation-rmse:5.11664
# [704]	validation-rmse:5.11664
# [705]	validation-rmse:5.11661
# [706]	validation-rmse:5.11654
# [707]	validation-rmse:5.11656
# [708]	validation-rmse:5.11660
# [709]	validation-rmse:5.11661
# [710]	validation-rmse:5.11658
# [711]	validation-rmse:5.11652
# [712]	validation-rmse:5.11660
# [713]	validation-rmse:5.11665
# [714]	validation-rmse:5.11664
# [715]	validation-rmse:5.11666
# [716]	validation-rmse:5.11664
# [717]	validation-rmse:5.11656
# [718]	validation-rmse:5.11662
# [719]	validation-rmse:5.11659
# [720]	validation-rmse:5.11661
# [721]	validation-rmse:5.11666
# [722]	validation-rmse:5.11669
# [723]	validation-rmse:5.11667
# [724]	validation-rmse:5.11663
# [725]	validation-rmse:5.11665
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/codespace/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [10:51:43] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2024/09/19 10:51:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2023-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2023-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# 2024/09/19 11:14:30 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.5.1, but the installed version is 1.5.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2024/09/19 11:14:30 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 15
#      12 mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
#      14 mlmodel = model_class()
# ---> 15 mlmodel.fit(X_train, y_train)
#      17 y_pred = mlmodel.predict(X_val)
#      18 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:580, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     578     patch_function.call(call_original, *args, **kwargs)
#     579 else:
# --> 580     patch_function(call_original, *args, **kwargs)
#     582 session.state = "succeeded"
#     584 try_log_autologging_event(
#     585     AutologgingEventLogger.get_logger().log_patch_function_success,
#     586     session,
#    (...)
#     590     kwargs,
#     591 )
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:249, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     246     managed_run = create_managed_run()
#     248 try:
# --> 249     result = patch_function(original, *args, **kwargs)
#     250 except (Exception, KeyboardInterrupt):
#     251     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     252     # that runs are terminated if a user prematurely interrupts training execution
#     253     # (e.g. via sigint / ctrl-c)
#     254     if managed_run:
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:1653, in _autolog.<locals>.patched_fit(fit_impl, allow_children_patch, original, self, *args, **kwargs)
#    1649 if t.should_log():
#    1650     # In `fit_mlflow` call, it will also call metric API for computing training metrics
#    1651     # so we need temporarily disable the post_training_metrics patching.
#    1652     with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> 1653         result = fit_impl(original, self, *args, **kwargs)
#    1654     if should_log_post_training_metrics:
#    1655         _AUTOLOGGING_METRICS_MANAGER.register_model(
#    1656             self, mlflow.active_run().info.run_id
#    1657         )
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:1428, in _autolog.<locals>.fit_mlflow(original, self, *args, **kwargs)
#    1426 _log_pretraining_metadata(autologging_client, self, X, y_true)
#    1427 params_logging_future = autologging_client.flush(synchronous=False)
# -> 1428 fit_output = original(self, *args, **kwargs)
#    1429 _log_posttraining_metadata(autologging_client, self, X, y_true, sample_weight)
#    1430 autologging_client.flush(synchronous=True)
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:561, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     558         original_result = original(*_og_args, **_og_kwargs)
#     559         return original_result
# --> 561 return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:496, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     487 try:
#     488     try_log_autologging_event(
#     489         AutologgingEventLogger.get_logger().log_original_function_start,
#     490         session,
#    (...)
#     494         og_kwargs,
#     495     )
# --> 496     original_fn_result = original_fn(*og_args, **og_kwargs)
#     498     try_log_autologging_event(
#     499         AutologgingEventLogger.get_logger().log_original_function_success,
#     500         session,
#    (...)
#     504         og_kwargs,
#     505     )
#     506     return original_fn_result
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:558, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     550 # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     551 # during original function execution, even if silent mode is enabled
#     552 # (`silent=True`), since these warnings originate from the ML framework
#     553 # or one of its dependencies and are likely relevant to the caller
#     554 with set_non_mlflow_warnings_behavior_for_current_thread(
#     555     disable_warnings=False,
#     556     reroute_warnings=False,
#     557 ):
# --> 558     original_result = original(*_og_args, **_og_kwargs)
#     559     return original_result
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File ~/anaconda3/envs/new-exp-tracking-env/lib/python3.9/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
logged_model = 'runs:/920b8deac31a43cba7d748b5332733f7/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 920b8deac31a43cba7d748b5332733f7
